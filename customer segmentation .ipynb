# %%
import numpy as np
# data framework manuplation
import pandas as pd
# for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# settling chart

# %%
plt.style.use('fivethirtyeight')

# %%
plt.rcParams['figure.figsize'] = (15, 5)

# %%
data =pd.read_csv(r'C:\Users\abhinav verma\Desktop\dataset/Mall_Customers.csv')

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.shape
# Out:
# (200, 5)

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
plt.figure(figsize=(20,10))
sns.pairplot(data)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data.corr()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
plt.figure(figsize=(8,8))
sns.heatmap(data.corr(),cbar=True, square=True, fmt='.1f', annot=True, annot_kws={'size': 8}, cmap='Blues')
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
# describe the categorical data
data.describe(include='object')
# Out:
#         Gender
# count      200
# unique       2
# top     Female
# freq       112

# %%
data.isnull().any().any()
# checking if there is any null data
# Out:
# False

# %% [markdown]
# ## data visualization

# %%
plt.rcParams['figure.figsize']=(18,8)
plt.subplot(1,2,1)
sns.set(style='whitegrid')
sns.distplot(data['Annual Income (k$)'])
plt.title('Distribution of Annual Income',fontsize=20)
plt.xlabel('Range ofAnnual income')
plt.ylabel('Counts')

plt.subplot(1,2,2)
sns.set(style='whitegrid')
sns.distplot(data['Age'],color='red')
plt.title('Distribution of Age',fontsize=20)
plt.xlabel('range of Age')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# so here we conclude the number of mist visiter income is between 50 t0 80 (k$) and the age of people visiting most is between 30 to 40

# %%
labels =['Male','Female']
size=data['Gender'].value_counts()
colors=['green','Blue']
explode=[0, 0.001]
plt.rcParams['figure.figsize']=(4,4)
plt.pie(size,colors=colors,explode=explode,labels =labels,shadow=True,startangle=90,autopct='%.2f%%')
plt.title('Gender Gap', fontsize=20)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.rcParams['figure.figsize'] = (15, 8)

# Create the count plot for 'Age' using the 'data' parameter
sns.countplot(data=data, x='Age', palette='hsv')

# Set the title
plt.title('Distribution of Age', fontsize=20)

# Show the plot
plt.show()

# %%
plt.rcParams['figure.figsize']=(20,9)
sns.distplot(data['Annual Income (k$)'],color='Red' )
plt.title('distribution of income',fontsize=20)
plt.show()

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
#check the distribution of spending score
plt.rcParams['figure.figsize']=(20,9)
sns.distplot(data[ 'Spending Score (1-100)'],color='Black' )
plt.title('distribution of Spending Score',fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.rcParams['figure.figsize'] = (18, 7)

# Create a violin plot for 'Gender' vs 'Annual Income (k$)'
sns.violinplot(x='Gender', y='Annual Income (k$)', data=data, palette='Blues')

# Set the title
plt.title('Gender vs Annual Income', fontsize=20)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.rcParams['figure.figsize'] = (18, 7)

# Create a violin plot for 'Gender' vs 'Annual Income (k$)'
sns.boxenplot(x='Gender', y='Spending Score (1-100)', data=data, palette='Blues')

# Set the title
plt.title('Gender vs Spending Score', fontsize=20)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.rcParams['figure.figsize'] = (18, 7)

# Create a violin plot for 'Gender' vs 'Annual Income (k$)'
sns.stripplot(x='Gender', y='Age', data=data, palette='Purples')

# Set the title
plt.title('Gender vs Age', fontsize=20)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.rcParams['figure.figsize'] = (18, 7)

# Define your data
x = data['Annual Income (k$)']
y = data['Age']
z = data['Spending Score (1-100)']

# Create line plots for 'Annual Income (k$) vs Age' and 'Annual Income (k$) vs Spending Score (1-100)'
sns.lineplot(x=x, y=y, color='blue', label='Age')
sns.lineplot(x=x, y=z, color='pink', label='Spending Score (1-100)')

# Set the title and legend
plt.title('Annual Income vs Age and Spending Score', fontsize=20)
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Clustering Analysis

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
x=data.loc[:,['Spending Score (1-100)','Annual Income (k$)']].values
print(x.shape)
# Out:
# (200, 2)

# %%
y=data.loc[:,['Age','Spending Score (1-100)']].values
print(x.shape)
# Out:
# (200, 2)

# %%
xdata= pd.DataFrame(x)

# %%
xdata.shape
# Out:
# (200, 2)

# %%
xdata.head()
# Out:
#     0   1
# 0  39  15
# 1  81  15
# 2   6  16
# 3  77  16
# 4  40  17

# %% [markdown]
# # K-mean Algorithrm

# %% [markdown]
# use elbow method to find optimal clusters

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

wcss = []

for i in range(1, 11):
    km = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    # Assuming you have data to fit, e.g., km.fit(data)
    # Replace 'data' with your actual data
    km.fit(x)
    wcss.append(km.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method', fontsize=20)
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# Sample data (replace this with your actual data)
x = np.random.rand(200, 2)

plt.style.use('fivethirtyeight')

km = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s=100, c='Pink', label='miser')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s=100, c='Yellow', label='general')
plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s=100, c='Cyan', label='target')
plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s=100, c='Magenta', label='spendthrift')
plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s=100, c='Orange', label='careful')
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], s=50, c='Blue', label='centroid')

plt.title('KMeans Clustering between Annual Income and Spending Score', fontsize=20)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.legend()
plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

wcss = []

for i in range(1, 11):
    km = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    # Assuming you have data to fit, e.g., km.fit(data)
    # Replace 'data' with your actual data
    km.fit(y)
    wcss.append(km.inertia_)

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method', fontsize=20)
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# Sample data (replace this with your actual data)
x = np.random.rand(200, 2)

plt.style.use('fivethirtyeight')

km = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10, random_state=0)
z_means = km.fit_predict(y)

plt.scatter(y[z_means == 0, 0], y[z_means == 0, 1], s=100, c='Pink', label='Unusual customers')
plt.scatter(y[z_means == 1, 0], y[z_means == 1, 1], s=100, c='Orange', label='priority customers')
plt.scatter(y[z_means == 2, 0], y[z_means == 2, 1], s=100, c='Lightgreen', label='target customers(young)')
plt.scatter(y[z_means == 3, 0], y[z_means == 3, 1], s=100, c='Red', label='target customers(young)')
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], s=50, c='Black', label='centroid')

plt.title('KMeans Clustering between Age and Spending Score', fontsize=20)
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.legend()
plt.grid()

plt.show()
